# %%
from google.colab import drive
drive.mount('/content/gdirve')
# Out:
# Mounted at /content/gdirve

# %%
cd /content/gdirve/My Drive/Colab Notebooks/HNCdata
# Out:
# /content/gdirve/My Drive/Colab Notebooks/HNCdata

# %%
import time, psutil
uptime = time.time() - psutil.boot_time()
remain = 12*60*60 - uptime
print('time_remain:', remain/60/60)
print(uptime/60/60)
# 7.328266562157207
# 4.671733437842793
# 6.362646000054147
# 5.637353999945853
# 5.639762876629829
# 6.360237123370171
# Out:
# time_remain: 11.964936015473473
# 0.03506398452652825

# %%
from bs4 import BeautifulSoup
import os
import urllib.request
import requests
import pandas as pd

obj_dct = []
# dct_link = {'CPU' : '/cpu-bo-vi-xu-ly','MAIN' : '/mainboard-bo-mach-chu', 
#             'RAM' : '/ram-bo-nho-trong', 'HDD' : '/o-cung-hdd-desktop', 
#             'SSD' : '/o-cung-ssd', 'VGA' : '/vga-card-man-hinh', 
#             'CASE' : '/vo-case', 'PSU' : '/nguon-may-tinh', 
#             'FAN' : '/tan-nhiet-cooling', 'KEY_BOARD' : '/ban-phim-may-tinh', 
#             'MOUSE' : '/chuot-may-tinh', 'MONITOR' : '/man-hinh-may-tinh'
# }

dct_link = {'MAIN' : '/mainboard-bo-mach-chu'}
try:
    os.mkdir('img/')
except:
    None
try:
    os.mkdir('Csv/')
except:
    None
try:
    os.mkdir('Error/')
except:
    None
try:
    os.mkdir('Category/')
except:
    None
link = "https://www.hanoicomputer.vn"


def claw_infor_objects(key, url):
    error_object = []
    infor_object = []
    category_object = []
    source = urllib.request.urlopen(url)
    soup = BeautifulSoup(source)
    # find and count pages
    page_max = soup.find('div', class_='paging').find_all('a')[-2].contents[0]
    # edit url for per page
    try:
        os.mkdir('img/'+key)
    except:
        None
    for page_number in range(int(page_max)+1):
        current_url = url + '/'+str(page_number)+'/'
        source = urllib.request.urlopen(current_url)
        soup = BeautifulSoup(source)
        # print(soup.prettify) 

        # download file.html
        # file_name = soup.title.string+'.html'
        # urllib.request.urlretrieve(link, file_name)

        lst_objs = soup.find_all('div', class_='p-component item')
        for obj in lst_objs:
            code = ''
            name = ''
            base_price = ''
            sale_price = ''
            link_img = ''
            Product_parameters = []
            # find code object
            p_tag = obj.find_all('p', class_="p-sku")
            for i in p_tag:
                if 'Mã SP' in str(i):
                    p_tag = str(i.contents[0]).split(' ')
                    code = p_tag[-1]
            # div p-info
            infor_objs = obj.find('div', {'class': 'p-info'})
            name = str(infor_objs.h3.a.contents[0]) # name object
            price_objs = infor_objs.find('span', class_='p-price js-get-minPrice')
            sale_price = str(price_objs.attrs['data-price']) # sale price
            base_price = str(price_objs.attrs['data-marketprice']) # base price
            hover_infor = obj.find_all('div', class_="hover_content_pro tooltip-2019")
            try:
                obj_parameters = hover_infor[0].find('div', {'class': 'hover_offer '}).contents # content cua thong so san pham
                for i in range(0, len(obj_parameters)-1, 2):
                    infor = obj_parameters[i].split('\n                    ')[-1]
                    if ' ' is infor or '\n' is infor:
                        None
                    else:
                        Product_parameters.append(infor)
            except:
                Product_parameters = ['']
            warranty_objs = hover_infor[0].find_all('tr')[2].find_all('td')
            if len(warranty_objs) == 2:
                if 'Bảo hành' in str(warranty_objs[0]):
                    if 'tháng' in str(warranty_objs[1]):
                        warranty_objs = str(warranty_objs[1]).split('<td>')[1].split('</td>')[0]
                    else:
                        warranty_objs = '24 tháng'
            link_img = obj.find('img', class_='lazy').attrs['data-src']
            # print(link_img)

            # if obj have an image => save obj, else save obj an error
            file_name = link_img.split('/')[-1]
            Img_directory = 'img/'+key+'/'+file_name
            try: 
                with open('img/'+key+'/'+file_name, mode='wb') as f:
                    respons = requests.get(link_img)
                    f.write(respons.content)
                infor_object.append({'Code': code, 'Name': name, 'Bao hanh': warranty_objs,
                                     'Base_price': base_price, 'Slase_price': sale_price,
                                     'Img_directory': Img_directory,
                                     'Thong so san pham': Product_parameters})
                category_object.append({'Code': code, 'Name': name})
            except:
                error_object.append({'Code': code, 'Name': name, 'Bao hanh': warranty_objs,
                                     'Base_price': base_price, 'Slase_price': sale_price,
                                     'Img_directory': Img_directory,
                                     'Thong so san pham': Product_parameters})
            print(f"Code:               {code}")
            print(f"Name:               {name}")
            print(f'Base_price:         {base_price}')
            print(f'Sale_price:         {sale_price}')
            print(f'Img_directory:      {Img_directory}')
            print(f'URL:                {current_url}')
            print(f'Thong so san pham:  {Product_parameters}')
            print(f'Bao hanh:           {warranty_objs}')
            print('*'*80)

    return infor_object, error_object, category_object

# Call func 
# claw_infor_objects(url)
for key, value in dct_link.items():
    url = link + value
    print(url)
    print('-'*80)
    obj_dct = claw_infor_objects(key, url)
    csv_file_name = 'Csv/'+key+'.csv'
    error_file_name = 'Error/'+key+'.csv'
    category_file_name = 'Category/category_'+key+'.csv'
    df = pd.DataFrame(obj_dct[0])
    df_error = pd.DataFrame(obj_dct[1])
    df_category = pd.DataFrame(obj_dct[2])
    df.to_csv(csv_file_name)
    df_error.to_csv(error_file_name)    
    df_category.to_csv(category_file_name, index=False)
    # print(obj_dct)
# Out:
# https://www.hanoicomputer.vn/mainboard-bo-mach-chu
# --------------------------------------------------------------------------------
# Code:               MBAS558
# Name:               Mainboard ASUS ROG MAXIMUS XII FORMULA (Intel Z490, Socket 1200, ATX, 4 khe RAM DDR4)
# Base_price:         0
# Sale_price:         0
# Img_directory:      img/MAIN/250_52342_rog_maximus_xii_formula_01.jpg
# URL:                https://www.hanoicomputer.vn/mainboard-bo-mach-chu/0/
# Thong so san pham:  ['- Chuẩn mainboard: ATX\r', '- Socket: 1200, Chipset: Z490\r', '- Hỗ trợ RAM: 4 khe DDR4, tối đa 128GB\r', '- Lưu trữ:  3 x M.2 NVMe, 6 x SATA 3 6Gb/s\r', '- Cổng xuất hình: Không']
# Bao hanh:           36 tháng
# ********************************************************************************
# Code:               MBAS588
# Name:               Mainboard ASUS PRIME H410M-A (Intel H410, Socket 1200, m-ATX, 2 khe Ram DDR4)
# Base_price:         0
# Sale_price:         1959000
# Img_directory:      img/MAIN/250_52872_prime_h410m_a_01.png
# URL:                https://www.hanoicomputer.vn/mainboard-bo-mach-chu/0/
# Thong so san pham:  ['- Kích thước: M-ATX\r', '- Socket: LGA 1200\r', '- Chipset: H410\r', '- Khe RAM tối đa: 2\r', '- Loại RAM hỗ trợ: DDR4']
# Bao hanh:           24 tháng
# ********************************************************************************
# Code:               MBAS579
# Name:               Mainboard ASUS ROG STRIX B460-H GAMING (Intel B460, Socket 1200, ATX, 4 khe Ram DDR4)
# Base_price:         0
# Sale_price:         3459000
# Img_directory:      img/MAIN/250_52863_rog_strix_b460_h_gaming_01_01.jpg
# URL:                https://www.hanoicomputer.vn/mainboard-bo-mach-chu/0/
# Thong so san pham:  ['- Kích thước: ATX\r', '- Socket: LGA1200\r', '- Chipset: B460\r', '- Khe RAM tối đa: 4\r', '- Loại RAM hỗ trợ: DDR4']
# Bao hanh:           24 tháng
# ********************************************************************************
# Code:               MBAS581
# Name:               Mainboard ASUS TUF GAMING B460-PRO (WIFI) (Intel B460, Socket 1200, ATX, 4 khe Ram DDR4)
# Base_price:         0
# Sale_price:         0
# Img_directory:      img/MAIN/250_52865_tuf_gaming_b460_pro__wi_fi__01_01.jpg
# URL:                https://www.hanoicomputer.vn/mainboard-bo-mach-chu/0/
# Thong so san pham:  ['- Kích thước: ATX\r', '- Socket: LGA1200\r', '- Chipset: B460\r', '- Khe RAM tối đa: 4\r', '- Loại RAM hỗ trợ: DDR4']
# Bao hanh:           24 tháng
# ********************************************************************************
# Code:               MBAS535
# Name:               Mainboard ASUS ROG STRIX X570-E GAMING (AMD X570, Socket AM4, ATX, 4 khe RAM DDR4)
# Base_price:         0
# Sale_price:         9349000
# Img_directory:      img/MAIN/250_47571_rog_strix_x570_e_gaming_aura_sync_01.png
# URL:                https://www.hanoicomputer.vn/mainboard-bo-mach-chu/0/
# Thong so san pham:  ['- Kích thước: ATX\r', '- Socket: AM4\r', '- Chipset: X570\r', '- Khe RAM tối đa: 4\r', '- Loại RAM hỗ trợ: DDR4']
# Bao hanh:           24 tháng
# ********************************************************************************
# Code:               MBAS534
# Name:               Mainboard ASUS ROG X570 CROSSHAIR VIII HERO (AMD X570, Socket AM4, ATX, 4 khe RAM DDR4)
# Base_price:         0
# Sale_price:         11399000
# Img_directory:      img/MAIN/250_47570_rog_crosshair_viii_hero_aura_sync_01.png
# URL:                https://www.hanoicomputer.vn/mainboard-bo-mach-chu/0/
# Thong so san pham:  ['- Ổ cắm AMD AM4: Hỗ trợ các bộ xử lý AMD Ryzen™ thế hệ thứ 2 và thứ 3 và tới hai ổ M.2, USB 3.2 Gen2 và AMD StoreMI để tối tối đa khả năng kết nối và tốc độ.\r', '- Thiết kế tản nhiệt toàn diện: Quạt tản nhiệt chipset chủ động, quạt tản nhiệt M.2 bằng nhôm và khu vực làm mát ROG.\r', '- Bộ nguồn ổn định: Thiết kế bộ nguồn với 14+2 pha cấp điện IR3555 PowIRstages, ProCool II, cuộn cảm lõi sắt từ và tụ điện kim loại đen 10K do Nhật Bản sản xuất.\r', '- Mạng hiệu suất cao: Wi-Fi 6 tích hợp (802.11ax) hỗ trợ MU-MIMO, 2.5 Gbps Ethernet và Gigabit Ethernet, cả hai đều được trang bị công nghệ bảo vệ ASUS LANGuard và hỗ trợ phần mềm GameFirst V.\r', '- Tối ưu 5 Chiều: Hiệu chỉnh tự động toàn hệ thống, cung cấp các hồ sơ ép xung và làm mát được tùy chỉnh cho hệ thống của bạn.\r']
# Bao hanh:           24 tháng
# ********************************************************************************
# Code:               MBAS533
# Name:               Mainboard ASUS ROG X570 CROSSHAIR VIII HERO Wifi (AMD X570, Socket AM4, ATX, 4 khe RAM DDR4)
# Base_price:         0
# Sale_price:         11899000
# Img_directory:      img/MAIN/250_47569_rog_crosshair_viii_hero__wi_fi__aura_sync_01.png
# URL:                https://www.hanoicomputer.vn/mainboard-bo-mach-chu/0/
# Thong so san pham:  ['- Mainboard Asus Rog Crosshair VIII Hero (WI-FI)\r', '- Chuẩn mainboard: ATX\r', '- Socket: AM4 , Chipset: X570\r', '- Hỗ trợ RAM: DDR4 , tối đa 64GB\r', '- Cổng cắm lưu trữ: 1 x M.2 NVMe; 1 x M.2 SATA/NVMe; 6 x SATA 3 6Gb/s']
# Bao hanh:           24 tháng
# ********************************************************************************
# Code:               MBAS532
# Name:               Mainboard ASUS ROG X570 CROSSHAIR VIII FORMULA (AMD X570, Socket AM4, ATX, 4 khe RAM DDR4)
# Base_price:         0
# Sale_price:         21699000
# Img_directory:      img/MAIN/250_47568_rog_crosshair_viii_formula_aura_sync_01.png
# URL:                https://www.hanoicomputer.vn/mainboard-bo-mach-chu/0/
# Thong so san pham:  ['- Socket: AM4 hỗ trợ CPU AMD thế hệ 3\r', '- Kích thước: ATX\r', '- Khe cắm RAM: 4 khe (Tối đa 128GB)\r', '- Khe cắm mở rộng: 2 x PCIe 4.0/3.0 x16\r', '- Khe cắm ổ cứng: 1 x M.2, 8 x SATA 6Gb/s']
# Bao hanh:           24 tháng
# ********************************************************************************
# Code:               MBAS596
# Name:               Mainboard ASUS TUF GAMING B550-PLUS (AMD B550, Socket AM4, ATX, 4 khe RAM DRR4)
# Base_price:         4299000
# Sale_price:         4099000
# Img_directory:      img/MAIN/250_53324_tuf_b550_plus_gaming_1.jpg
# URL:                https://www.hanoicomputer.vn/mainboard-bo-mach-chu/0/
# Thong so san pham:  ['- Kích thước: ATX\r', '- Socket: AM4\r', '- Chipset: B550\r', '- Khe RAM tối đa: 4\r', '- Loại RAM hỗ trợ: DDR4']
# Bao hanh:           36 tháng
# ********************************************************************************
# Code:               MBAS597
# Name:               Mainboard ASUS TUF GAMING B550M-PLUS (AMD B550, Socket AM4, m-ATX, 4 khe RAM DRR4)
# Base_price:         4199000
# Sale_price:         3999000
# Img_directory:      img/MAIN/250_53325_tuf_gaming_b550m_plus_01.jpg
# URL:                https://www.hanoicomputer.vn/mainboard-bo-mach-chu/0/
# Thong so san pham:  ['- Kích thước: M-ATX\r', '- Socket: AM4\r', '- Chipset: B550\r', '- Khe RAM tối đa: 4\r', '- Loại RAM hỗ trợ: DDR4']
# Bao hanh:           36 tháng
# ********************************************************************************
# Code:               MBAS598
# Name:               Mainboard ASUS TUF GAMING B550M-PLUS (WI-FI) (AMD B550, Socket AM4, m-ATX, 4 khe RAM DRR4)
# Base_price:         4599000
# Sale_price:         4499000
# Img_directory:      img/MAIN/250_53326_tuf_gaming_b550m_plus__wi_fi__1.jpg
# URL:                https://www.hanoicomputer.vn/mainboard-bo-mach-chu/0/
# Thong so san pham:  ['- Kích thước: M-ATX\r', '- Socket: AM4\r', '- Chipset: B550\r', '- Khe RAM tối đa: 4\r', '- Loại RAM hỗ trợ: DDR4']
# Bao hanh:           36 tháng
# ********************************************************************************
# Code:               MBAS554
# Name:               Mainboard ASUS ROG STRIX B360-I GAMING (Intel B360 , Socket 1151, Mini ATX, 2 khe RAM DDR4)
# Base_price:         3699000
# Sale_price:         3299000
# Img_directory:      img/MAIN/250_51060_rog_strix_b360_i_gaming_01.png
# URL:                https://www.hanoicomputer.vn/mainboard-bo-mach-chu/0/
# Thong so san pham:  ['- Kích thước: ITX\r', '- Socket: 1151v2\r', '- Chipset: B360\r', '- Khe RAM tối đa: 2\r', '- Loại RAM hỗ trợ: DDR4']
# Bao hanh:           24 tháng
# ********************************************************************************
# Code:               MBAS525
# Name:               Mainboard ASUS ROG STRIX B365-F GAMING (Intel B365, Socket 1151, ATX, 4 khe RAM DDR4)
# Base_price:         3599000
# Sale_price:         3299000
# Img_directory:      img/MAIN/250_47176_rog_strix_b365_f_gaming_01.png
# URL:                https://www.hanoicomputer.vn/mainboard-bo-mach-chu/0/
# Thong so san pham:  ['- Socket: 1151 9th/8th Gen Intel Core, Pentium Gold and Celeron Processors\r', '- Kích thước: ATX\r', '- Khe cắm RAM: 4 khe (Tối đa 64GB)\r', '- Khe cắm mở rộng: 1 x PCIe 3.0/2.0 x16/1 x PCIe 3.0/2.0 x16 / 3 x PCIe 3.0/2.0 x1\r', '- Khe cắm ổ cứng: 1 x M.2 Socket 3/ 1 x M.2 Socket 3/ 6 x SATA 6Gb/s']
# Bao hanh:           24 tháng
# ********************************************************************************
# Code:               MBAS522
# Name:               Mainboard ASUS ROG MAXIMUS XI APEX (Intel Z390,Socket 1151, ATX, 2 khe RAM DDR4)
# Base_price:         0
# Sale_price:         9699000
# Img_directory:      img/MAIN/250_45816_rog_maximus_xi_apex_z390_10.png
# URL:                https://www.hanoicomputer.vn/mainboard-bo-mach-chu/0/
# Thong so san pham:  ['- Chuẩn mainboard: ATX \r', '- Socket: LGA 1151-v2 , Chipset: Z390 \r', '- Hỗ trợ RAM: DDR4 , tối đa 64GB \r', '- Cổng cắm lưu trữ: 1 x M.2 NVMe; 1 x M.2 SATA/NVMe; 6 x SATA 3 6Gb/s; Hỗ trợ Intel Optane \r', '- Cổng xuất hình: Không có']
# Bao hanh:           24 tháng
# ********************************************************************************
# Code:               MBAS548
# Name:               Mainboad ASUS ROG STRIX X299 - E GAMING II (Intel X299, Socket 2066, ATX,8 khe RAM DDR4)
# Base_price:         10899000
# Sale_price:         9399000
# Img_directory:      img/MAIN/250_49687_01_rog_strix_x299_e_gaming_ii.png
# URL:                https://www.hanoicomputer.vn/mainboard-bo-mach-chu/0/
# Thong so san pham:  ['- Sẵn sàng cho bộ xử lý Intel® Core ™ X-series mới nhất để tối đa hóa khả năng kết nối và tốc độ với tối đa ba ổ M.2, USB 3.2 Gen 2, Intel® VROC và Intel® Optane ™\r', '- Cá nhân hóa chưa từng có: Ánh sáng Aura Sync RGB dành riêng cho OLED và ASUS, bao gồm các chân kết nối RGB và các chân kết nối Gen 2 A-RGB\r', '- Giải pháp tối ưu: 12 phase nguồn với đầu nối nguồn ProCool II, cuộn cảm chất lượng cao và tụ điện bền để hỗ trợ bộ xử lý đa lõi\r', '- Làm mát toàn diện: Tản nhiệt chủ động VRM, tản nhiệt vây xếp chồng lên nhau, với ống tản nhiệt 8 mm, tản nhiệt M.2 kép trên bo mạch\r', '- Kết nối chơi game: Ba cổng M.2, USB 3.2 Type-C và đầu nối bảng mặt trước Type-C\r']
# Bao hanh:           24 tháng
# ********************************************************************************
# Code:               MBAS529
# Name:               Mainboard ASUS EX-B365M-V5 (Intel B365, Socket 1151, m-ATX, 2 khe RAM DDR4)
# Base_price:         1899000
# Sale_price:         1649000
# Img_directory:      img/MAIN/250_47480_01_ex_b365m_v5.png
# URL:                https://www.hanoicomputer.vn/mainboard-bo-mach-chu/0/
# Thong so san pham:  ['- Chipset: Intel B365\r', '- Socket: LGA1151\r', '- Hỗ trợ CPU: Intel® Socket 1151 9th / 8th Gen Intel® Core™, Pentium® Gold and Celeron® Processors. Supports Intel® 14 nm CPU.\r', '- Cạc đồ họa: VGA onboard\r', '- Kích thước: mATX']
# Bao hanh:           24 tháng
# ********************************************************************************
# Code:               MBAS495
# Name:               Mainboard ASUS PRIME B450M-A (AMD B450, Socket AM4, m-ATX, 4 khe RAM DDR4)
# Base_price:         1899000
# Sale_price:         1699000
# Img_directory:      img/MAIN/250_43238_01_prime_b450m_a.png
# URL:                https://www.hanoicomputer.vn/mainboard-bo-mach-chu/0/
# Thong so san pham:  ['- Bo mạch chủ AMD AM4 mATX DDR4 3200MHz, M.2, HDMI 2.0b, SATA 6Gbps và USB 3.1 Gen 2']
# Bao hanh:           24 tháng
# ********************************************************************************
# Code:               MBAS536
# Name:               Mainboard ASUS ROG STRIX Z390-E GAMING (Intel Z390, Socket 1151, ATX, 4 khe RAM DDR4)
# Base_price:         5699000
# Sale_price:         5599000
# Img_directory:      img/MAIN/250_48061_1__bo_mach_chu_gaming_cao_cap_asus_rog_strix_z390_e_gaming_aura_sync_hop_san_pham.png
# URL:                https://www.hanoicomputer.vn/mainboard-bo-mach-chu/0/
# Thong so san pham:  ['- Asus ROG STRIX Z390-E GAMING\r', '- Socket: LGA1151 hỗ trợ CPU intel thế hệ 8 và 9\r', '- Kích thước: ATX\r', '- Khe cắm RAM: 4 khe (Tối đa 64GB)\r', '- Khe cắm mở rộng: 3 x PCIe 3.0/2.0 x16, 3 x PCIe 3.0/2.0 x1\r']
# Bao hanh:           24 tháng
# ********************************************************************************
# Code:               MBAS505
# Name:               Mainboard ROG MAXIMUS XI HERO (Intel Z390, Socket 1151, ATX, 4 khe RAM DDR4)
# Base_price:         0
# Sale_price:         6999000
# Img_directory:      img/MAIN/250_44302__hinh_dai_dien__bo_mach_chu_gaming_cao_cap_mainboard_asus_rog_maximus_xi_hero_z390_aura_sync_hop_san_pham_01.png
# URL:                https://www.hanoicomputer.vn/mainboard-bo-mach-chu/0/
# Thong so san pham:  ['- Kích thước: ATX\r', '- Socket: LGA 1151v2\r', '- Chipset: Z390\r', '- Khe RAM tối đa: 4\r', '- Loại RAM hỗ trợ: DDR4']
# Bao hanh:           24 tháng
# ********************************************************************************
# Code:               MBAS539
# Name:               Mainboard ASUS ROG Z390 MAXIMUS XI HERO (WI-FI) (Intel Z390, Socket 1151, ATX, 4 khe RAM DDR4)
# Base_price:         0
# Sale_price:         7799000
# Img_directory:      img/MAIN/250_48772__hinh_dai_dien__bo_mach_chu_gaming_cao_cap_mainboard_asus_rog_maximus_xi_hero_z390_aura_sync_hop_san_pham_01.png
# URL:                https://www.hanoicomputer.vn/mainboard-bo-mach-chu/0/
# Thong so san pham:  ['- Socket LGA1151 cho các bộ xử lý máy tính bàn Intel® Core™ thế hệ thứ 8/9.\r', '- Công nghệ đèn RGB đồng bộ hóa hỗ trợ nhiều thiết bị PC tương thích Aura Sync và hỗ trợ các dải đèn địa chỉ và Phillip Hue\r', '- Bo mạch chủ được làm mát hoàn hảo với các vùng cổng cấp nước chuyên dụng, quạt tản nhiệt M.2 và điều khiển quạt đa dạng\r', '- Khả năng kết nối gaming: Intel Gigabit Ethernet , LANGaurd, M.2 kép, USB 3.1 Gen 2, Wi-Fi với MU-MI-MO 802.11\r', '- Tối ưu hóa 5 bước: Tự động điều chỉnh toàn hệ thống, hỗ trợ các tính năng ép xung và làm mát công nghệ AI dành riêng cho giàn máy của bạn\r']
# Bao hanh:           24 tháng
# ********************************************************************************
# Code:               MBAS573
# Name:               Mainboard ASUS ProArt Z490-CREATOR 10G (Intel Z490, Socket 1200, ATX, 4 khe RAM DDR4)
# Base_price:         0
# Sale_price:         8899000
# Img_directory:      img/MAIN/250_52357_proart_z490_creator_10g_01.jpg
# URL:                https://www.hanoicomputer.vn/mainboard-bo-mach-chu/0/
# Thong so san pham:  ['- Chuẩn mainboard: ATX\r', '- Socket: 1200, Chipset: Z490\r', '- Hỗ trợ RAM: 4 khe DDR4, tối đa 128GB\r', '- Lưu trữ:  2 x M.2 NVMe, 6 x SATA 3 6Gb/s\r', '- Cổng xuất hình: 1 x HDMI, 1 x DP']
# Bao hanh:           24 tháng
# ********************************************************************************
# Code:               MBAS542
# Name:               Mainboard Asus Pro WS X570-ACE
# Base_price:         0
# Sale_price:         8989000
# Img_directory:      img/MAIN/250_49338_pro_ws_x570_ace_1.png
# URL:                https://www.hanoicomputer.vn/mainboard-bo-mach-chu/0/
# Thong so san pham:  ['- Ba khe cắm PCIe 4.0 x16 với sự sắp xếp làn đường được tối ưu hóa 3 chiều x8 / x8 / x8 để tăng tốc khối lượng công việc ngày càng đa dạng\r', '- Bộ nhớ ECC đáng tin cậy và đáp ứng phù hợp cho các nhiệm vụ quan trọng\r', '- ASUS Control Center Express: Một tiện ích phần mềm được trang bị bộ điều khiển LAN GbE để quản lý ngoài băng tần để tăng cường kiểm soát mức phần cứng nhằm cải thiện hiệu quả CNTT\r', '- Lưu trữ cực nhanh: Lên đến 64Gbps M.2 & 32Gbps U.2, cộng với cổng USB 3.2 Gen 2 lên tới 10Gbps với cổng Type-A và Type-C\r', '- Tản nhiệt VRM cực kỳ hiệu quả: Tản nhiệt lớn, tản nhiệt và thiết kế quạt PCH tích hợp tối đa hóa diện tích bề mặt để tản nhiệt để cho phép hiệu suất vượt trội\r']
# Bao hanh:           24 tháng
# ********************************************************************************
# Code:               MBAS541
# Name:               Mainboard ASUS TUF GAMING X570 PLUS (Wi-Fi) (AMD X570, Socket AM4, ATX, 4 khe RAM DDR4)
# Base_price:         0
# Sale_price:         5999000
# Img_directory:      img/MAIN/250_49003_tuf_gaming_x570_plus__wi_fi__aura_sync_01.png
# URL:                https://www.hanoicomputer.vn/mainboard-bo-mach-chu/0/
# Thong so san pham:  ['- ASUS TUF - Bền. Ổn Định. Tin cậy\r', '- Hiệu suất mạnh mẽ với Dr.MOS, PCB 6 lớp, Chân cấp nguồn ProCool, Linh kiện chuẩn TUF, Digi+ VRM\r', '- Dễ vọc máy tính với TUF Gaming Alliance, TUF Protection, Armoury Crate\r', '- Intel Wireless-AC 9260 tích hợp Wi-Fi 5\r', '- Turbo LAN - Phần mềm tối ưu kết nối mạng cho khả năng tuỳ chỉnh mức ưu tiên các gói tin']
# Bao hanh:           24 tháng
# ********************************************************************************
# Code:               MBAS599
# Name:               Mainboard ASUS PRIME B550-PLUS (AMD B550, Socket AM4, ATX, 4 khe RAM DRR4)
# Base_price:         0
# Sale_price:         4299000
# Img_directory:      img/MAIN/250_53327_prime_b550_plus_1.jpg
# URL:                https://www.hanoicomputer.vn/mainboard-bo-mach-chu/0/
# Thong so san pham:  ['- Kích thước: ATX\r', '- Socket: AM4\r', '- Chipset: B550\r', '- Khe RAM tối đa: 4\r', '- Loại RAM hỗ trợ: DDR4']
# Bao hanh:           36 tháng
# ********************************************************************************
# Code:               MBAS601
# Name:               Mainboard ASUS PRIME B550M-A (WI-FI) (AMD B550, Socket AM4,m- ATX, 4 khe RAM DRR4)
# Base_price:         0
# Sale_price:         3799000
# Img_directory:      img/MAIN/250_53329_prime_b550m_a_1.jpg
# URL:                https://www.hanoicomputer.vn/mainboard-bo-mach-chu/0/
# Thong so san pham:  ['- Kích thước: M-ATX\r', '- Socket: AM4\r', '- Chipset: B550\r', '- Khe RAM tối đa: 4\r', '- Loại RAM hỗ trợ: DDR4']
# Bao hanh:           36 tháng
# ********************************************************************************
# Code:               MBAS602
# Name:               Mainboard ASUS PRIME B550M-K (AMD B550, Socket AM4,m- ATX, 4 khe RAM DRR4)
# Base_price:         0
# Sale_price:         3199000
# Img_directory:      img/MAIN/250_53330_prime_b550m_k_1.jpg
# URL:                https://www.hanoicomputer.vn/mainboard-bo-mach-chu/0/
# Thong so san pham:  ['- Kích thước: M-ATX\r', '- Socket: AM4\r', '- Chipset: B550\r', '- Khe RAM tối đa: 4\r', '- Loại RAM hỗ trợ: DDR4']
# Bao hanh:           36 tháng
# ********************************************************************************
# Code:               MBAS530
# Name:               Mainboard ASUS PRIME X570-P/CSM (AMD X570, Socket AM4, ATX, 4 khe RAM DDR4)
# Base_price:         0
# Sale_price:         4899000
# Img_directory:      img/MAIN/250_47566_prime_x570_p_aura_sync_01.png
# URL:                https://www.hanoicomputer.vn/mainboard-bo-mach-chu/0/
# Thong so san pham:  ['- Socket: AM4 hỗ trợ CPU AMD thế hệ 3\r', '- Kích thước: ATX\r', '- Khe cắm RAM: 4 khe (Tối đa 128GB)\r', '- Khe cắm mở rộng: 1 x PCIe 4.0/3.0 x16\r', '- Khe cắm ổ cứng: 1 x M.2, 6 x SATA 6Gb/s']
# Bao hanh:           24 tháng
# ********************************************************************************
# Code:               MBGI573
# Name:               Mainboard Gigabyte H410M-DS2V (Intel H410, Socket 1200, m-ATX, 2 khe Ram DDR4)
# Base_price:         0
# Sale_price:         1749000
# Img_directory:      img/MAIN/250_53232_gigabyte_h410_ds2v.jpg
# URL:                https://www.hanoicomputer.vn/mainboard-bo-mach-chu/0/
# Thong so san pham:  ['- Kích thước: Micro-ATX\r', '- Socket: LGA 1200\r', '- Chipset: H410\r', '- Khe RAM tối đa: 2\r', '- Loại RAM hỗ trợ: DDR4']
# Bao hanh:           36 tháng
# ********************************************************************************
# Code:               MBAS549
# Name:               Mainboad ASUS ROG RAMPAGE VI EXTREME ENCONRE (Intel X299, Socket 2066, E-ATX, 8 khe RAM DDR4)
# Base_price:         0
# Sale_price:         18599000
# Img_directory:      img/MAIN/250_49688_mainboad_asus_rog_rampage_vi_extreme_enconre_0001_2.jpg
# URL:                https://www.hanoicomputer.vn/mainboard-bo-mach-chu/0/
# Thong so san pham:  ['- Sẵn sàng cho bộ xử lý Intel® Core ™ X-series mới nhất để tối đa hóa khả năng kết nối và tốc độ với tối đa bốn ổ M.2, USB 3.2 Gen 2x2, Intel® VROC và Intel® Optane ™\r', '- Cung cấp năng lượng mạnh mẽ: Giải pháp năng lượng được tối ưu hóa với 16 phase nguồn Infineon TDA21472, đầu nối nguồn ProCool II, cuộn cảm hợp kim MicroFine và tụ điện 10K\r', '- Ép xung AI: Tối ưu hóa nhanh chóng hiệu suất CPU của bạn dựa trên CPU và bộ làm mát, đạt được kết quả cực kỳ gần với điều chỉnh thủ công của các chuyên gia\r', '- Thiết kế nhiệt toàn diện: Tản nhiệt VRM làm mát chủ động, tản nhiệt nhôm PCIe vùng M.2, tấm ốp lưng,...\r', '- Kết nối mạng hiệu năng cao: Onboard Aquantia® 10 Gbps Ethernet, Wi-Fi 6 (802.11ax) có hỗ trợ MU-MIMO và công nghệ GameFirst V\r']
# Bao hanh:           24 tháng
# ********************************************************************************
# Code:               MBAS492
# Name:               Mainboard ASUS ROG STRIX B450-F GAMING (AMD B450, Socket AM4, ATX, 4 khe RAM DDR4)
# Base_price:         3299000
# Sale_price:         2999000
# Img_directory:      img/MAIN/250_43236_mainboard_asus_rog_strix_b450_f_gaming_0000_1.jpg
# URL:                https://www.hanoicomputer.vn/mainboard-bo-mach-chu/0/
# Thong so san pham:  ['- Kích thước: ATX\r', '- Socket: AM4\r', '- Chipset: B450\r', '- Khe RAM tối đa: 4\r', '- Loại RAM hỗ trợ: DDR4']
# Bao hanh:           24 tháng
# ********************************************************************************
# Code:               MBAR240
# Name:               Mainboard ASROCK B365M-HDV (Intel B365, Socket 1151, m-ATX, 2 khe RAM DDR4)
# Base_price:         1699000
# Sale_price:         1599000
# Img_directory:      img/MAIN/250_48190_mainboard_asrock_b365m_hdv_0004_5.jpg
# URL:                https://www.hanoicomputer.vn/mainboard-bo-mach-chu/0/
# Thong so san pham:  ['- Socket: LGA1151 hỗ trợ CPU intel thế hệ 8 và 9\r', '- Kích thước: m-ATX\r', '- Khe cắm RAM: 2 khe (Tối đa 32GB)\r', '- Khe cắm mở rộng: 1 x PCIe 3.0 x16, 2 x PCIe 3.0 x1\r', '- Khe cắm ổ cứng: 6 x SATA3, 1 x Ultra M.2']
# Bao hanh:           24 tháng
# ********************************************************************************
# Code:               MBAS484
# Name:               Mainboard Asus Z11PA-D8 (Dual CPU Server & Workstation)
# Base_price:         0
# Sale_price:         15999000
# Img_directory:      img/MAIN/250_42754_mainboard_asus_z11pa_d8_dual_cpu_server_amp_workstation_0000_1.jpg
# URL:                https://www.hanoicomputer.vn/mainboard-bo-mach-chu/0/
# Thong so san pham:  ['- Được hỗ trợ bởi nền tảng Intel® Xeon® Scalable có 8 khe DIMM hỗ trợ 3DS ECC RDIMMS hoặc LRDIMMS hỗ trợ lên đến DDR4-2666 và 4 cổng mạng Gigabit LAN cùng một LAN quản lý chuyên dụng. Z11PE-D8 mang lại dung lượng bộ nhớ và băng thông dữ liệu tốt nhất.\r', '- Bo mạch chủ kích cỡ CEB với lỗ gắn chuẩn ATX để gắn linh hoạt  vừa với các case phôt thông, tháp, hoặc rack có kích thước nhỏ gọn 12 ”x 10.5” dành cho nhóm SMB (Small Business), Print / File / Mail, Máy chủ lưu trữ phổ thông, xử lý số liệu, Render...']
# Bao hanh:           24 tháng
# ********************************************************************************
# Code:               MBGI512
# Name:               Mainboard GIGABYTE Z390 Aorus Pro (Wifi) (Intel Z390, Socket 1151, ATX, 4 khe RAM DDR4)
# Base_price:         5499000
# Sale_price:         5199000
# Img_directory:      img/MAIN/250_44260_mainboardgigabyte_z390_aorus_pro_wifi_0000_1.jpg
# URL:                https://www.hanoicomputer.vn/mainboard-bo-mach-chu/0/
# Thong so san pham:  ['- Socket: LGA1151 hỗ trợ CPU intel thế hệ 8 và 9\r', '- Kích thước: ATX\r', '- Khe cắm RAM: 4 khe (Tối đa 64GB)\r', '- Khe cắm mở rộng: 3 x PCIe 3.0 x16, 3 x PCIe 3.0 x1, 1 x M.2 Socket 1\r', '- Khe cắm ổ cứng: 6 x SATA 6Gb/s, 2 x M.2 Socket 3']
# Bao hanh:           24 tháng
# ********************************************************************************
# Code:               MBAS513
# Name:               Mainboard ASUS ROG Z390 MAXIMUS XI EXTREME (Intel Z390,Socket 1151, ATX, 4 khe RAM DDR4)
# Base_price:         0
# Sale_price:         12099000
# Img_directory:      img/MAIN/250_44894__h__nh______i_di___n_bo_mach_chu_gaming_cao_cap_asus_rog_maximus_xi_extreme_z390_aura_sync_hop_san_pham.png
# URL:                https://www.hanoicomputer.vn/mainboard-bo-mach-chu/0/
# Thong so san pham:  ['- Socket LGA1151: Hỗ trợ các bộ xử lý máy tính Intel® Core™ thế hệ thứ 8/9.\r', '- Công nghệ đèn RGB đồng bộ hóa: Hỗ trợ nhiều thiết bị PC tương thích Aura Sync và hỗ trợ các dải đèn địa chỉ và Phillip Hue.\r', '- Làm mát hoàn hảo: Vùng làm mát bằng nước chuyên dụng, quạt tản nhiệt M.2 và điều khoản quạt linh hoạt.\r', '- ROG DIMM.2: Cạc mở rộng M.2 kép được lắp thẳng đứng với quạt tản nhiệt để làm mát và đẩm hiệu suất tối ưu.\r', '- Tối ưu hóa 5 chiều: Tự động điều chỉnh toàn hệ thống, hỗ trợ các tính năng ép xung và làm mát công nghệ AI dành riêng cho giàn máy của bạn.\r']
# Bao hanh:           24 tháng
# ********************************************************************************
# Code:               MBGI545
# Name:               Mainboard GIGABYTE TRX40 AORUS MASTER (AMD TRX40, Socket  sTRX4, E-ATX, 8 khe RAM DDR4)
# Base_price:         14399000
# Sale_price:         13299000
# Img_directory:      img/MAIN/250_50399_gigabyte_trx40_aorus_master_1.jpg
# URL:                https://www.hanoicomputer.vn/mainboard-bo-mach-chu/0/
# Thong so san pham:  ['- Chipset : AMD TRX40\r', '- Socket : sTRX4 \r', '- CPU hỗ trợ :AMD Socket sTRX4 for 3rd Gen AMD Ryzen™ Threadripper™ Series Desktop Processors\r', '- Kích thước : E-ATX']
# Bao hanh:           24 tháng
# ********************************************************************************
# Code:               MBGI565
# Name:               Mainboard Gigabyte B460M D2V (Intel B460, Socket 1200, m-ATX, 2 khe RAM DDR4)
# Base_price:         0
# Sale_price:         1999000
# Img_directory:      img/MAIN/250_52905_gigabyte_b460m_d2v.jpg
# URL:                https://www.hanoicomputer.vn/mainboard-bo-mach-chu/0/
# Thong so san pham:  ['- Kích thước: Micro-ATX\r', '- Socket: LGA 1200\r', '- Chipset: B460\r', '- Khe RAM tối đa: 2\r', '- Loại RAM hỗ trợ: DDR4']
# Bao hanh:           36 tháng
# ********************************************************************************
# Code:               MBAS368
# Name:               Mainboard ASUS Z10PE-D8 WS (DUAL CPU WORKSTATION)
# Base_price:         0
# Sale_price:         14289000
# Img_directory:      img/MAIN/250_42896_mainboard_asus_z10pe_d8_ws_dual_cpu_workstation_0001_2.jpg
# URL:                https://www.hanoicomputer.vn/mainboard-bo-mach-chu/0/
# Thong so san pham:  ['- Sức mạnh Đồ họa Gấp Bốn – Liên kết PCI-E Gen3 x16 4 Chiều hỗ trợ NVidia GeForce SLI và AMD CrossFireX theo yêu cầu \r', '- Giải pháp Điện năng Tuyệt đối – Các linh kiện cao cấp cho hiệu quả sử dụng điện năng hàng đầu \r', '- BIOS độc đáo để ép xung Hai CPU – Tăng hiệu năng ép xung của CPU lên đến 10% \r', '- Khả năng lưu trữ linh hoạt vượt trội – M.2 x4 tích hợp trên bo mạch và có hỗ trợ các card ASUS PIKE II \r', '- Dễ bảo trì – ASUS Q-Code Logger, một nút bảo trì tiện lợi và đèn hiển thị LED Dr. Power báo hiệu các tình trạng điện năng bất thường']
# Bao hanh:           24 tháng
# ********************************************************************************
# Code:               MBMS356
# Name:               Mainboard MSI B365M Mortar (Intel B365, Socket 1151, m-ATX, 4 khe RAM DDR4)
# Base_price:         2399000
# Sale_price:         2199000
# Img_directory:      img/MAIN/250_48020_mainboard_msi_b365m_mortar_0004_5.jpg
# URL:                https://www.hanoicomputer.vn/mainboard-bo-mach-chu/0/
# Thong so san pham:  ['- Kích thước: Micro-ATX \r', '- Socket: LGA 1151-v2\r', '- Chipset: B365\r', '- Khe RAM tối đa: 4\r', '- Bus RAM hỗ trợ: 2133MHz ;2400MHz ;2666MHz']
# Bao hanh:           24 tháng
# ********************************************************************************
# Code:               MBGI566
# Name:               Mainboard Gigabyte B460M DS3H (Intel B460, Socket 1200, m-ATX, 4 khe RAM DDR4)
# Base_price:         0
# Sale_price:         2199000
# Img_directory:      img/MAIN/250_52906_gigabyte_b460m_ds3h.jpg
# URL:                https://www.hanoicomputer.vn/mainboard-bo-mach-chu/0/
# Thong so san pham:  ['- Kích thước: Micro-ATX\r', '- Socket: LGA 1200\r', '- Chipset: B460\r', '- Khe RAM tối đa: 4\r', '- Loại RAM hỗ trợ: DDR4']
# Bao hanh:           36 tháng
# ********************************************************************************
# Code:               MBAS502
# Name:               Mainboard ASUS ROG Z390 MAXIMUS XI FORMULA (Intel Z390 ,Socket 1151,ATX,4 khe RAM DDR4)
# Base_price:         11199000
# Sale_price:         10899000
# Img_directory:      img/MAIN/250_44254_hinh_dai_dien_bo_mach_chu_gaming_cao_cap_asus_rog_maximus_xi_formula_z390_aura_sync_hop_san_pham_01.png
# URL:                https://www.hanoicomputer.vn/mainboard-bo-mach-chu/0/
# Thong so san pham:  ['- Socket LGA1151 cho các bộ xử lý máy tính bàn Intel® Core™ thế hệ thứ 8/9.\r', '- CrossChill EK III và khu vực làm mát bằng nước: Giữ cho hệ thống của bạn mát khi hoạt động làm tăng nhiệt.\r', '- Hệ sinh thái ROG: Đèn Aura Sync RGB chuyên dụng của ASUS bao gồm các đầu gắn cho cả các dải đèn RGB tiêu chuẩn và địa chỉ.\r', '- Khả năng kết nối gaming: Các giắc nối Aquantia 5G LAN, Intel Gigabit Ethernet, LANGuard, 2x2 802.11ac Wi-Fi, M.2 kép, USB 3.1 Gen 2 Loại-A và Kiểu-C™.\r', '- Đổ mới: Tối ưu hóa 5 chiều: Tự động điều chỉnh toàn hệ thống, hỗ trợ các tính năng ép xung và làm mát công nghệ AI dành riêng cho giàn máy của bạn.\r']
# Bao hanh:           24 tháng
# ********************************************************************************
# Code:               MBAS558
# Name:               Mainboard ASUS ROG MAXIMUS XII FORMULA (Intel Z490, Socket 1200, ATX, 4 khe RAM DDR4)
# Base_price:         0
# Sale_price:         0
# Img_directory:      img/MAIN/250_52342_rog_maximus_xii_formula_01.jpg
# URL:                https://www.hanoicomputer.vn/mainboard-bo-mach-chu/1/
# Thong so san pham:  ['- Chuẩn mainboard: ATX\r', '- Socket: 1200, Chipset: Z490\r', '- Hỗ trợ RAM: 4 khe DDR4, tối đa 128GB\r', '- Lưu trữ:  3 x M.2 NVMe, 6 x SATA 3 6Gb/s\r', '- Cổng xuất hình: Không']
# Bao hanh:           36 tháng
# ********************************************************************************
# Code:               MBAS588
# Name:               Mainboard ASUS PRIME H410M-A (Intel H410, Socket 1200, m-ATX, 2 khe Ram DDR4)
# Base_price:         0
# Sale_price:         1959000
# Img_directory:      img/MAIN/250_52872_prime_h410m_a_01.png
# URL:                https://www.hanoicomputer.vn/mainboard-bo-mach-chu/1/
# Thong so san pham:  ['- Kích thước: M-ATX\r', '- Socket: LGA 1200\r', '- Chipset: H410\r', '- Khe RAM tối đa: 2\r', '- Loại RAM hỗ trợ: DDR4']
# Bao hanh:           24 tháng
# ********************************************************************************
# Code:               MBAS581
# Name:               Mainboard ASUS TUF GAMING B460-PRO (WIFI) (Intel B460, Socket 1200, ATX, 4 khe Ram DDR4)
# Base_price:         0
# Sale_price:         0
# Img_directory:      img/MAIN/250_52865_tuf_gaming_b460_pro__wi_fi__01_01.jpg
# URL:                https://www.hanoicomputer.vn/mainboard-bo-mach-chu/1/
# Thong so san pham:  ['- Kích thước: ATX\r', '- Socket: LGA1200\r', '- Chipset: B460\r', '- Khe RAM tối đa: 4\r', '- Loại RAM hỗ trợ: DDR4']
# Bao hanh:           24 tháng
# ********************************************************************************
# Code:               MBAS579
# Name:               Mainboard ASUS ROG STRIX B460-H GAMING (Intel B460, Socket 1200, ATX, 4 khe Ram DDR4)
# Base_price:         0
# Sale_price:         3459000
# Img_directory:      img/MAIN/250_52863_rog_strix_b460_h_gaming_01_01.jpg
# URL:                https://www.hanoicomputer.vn/mainboard-bo-mach-chu/1/
# Thong so san pham:  ['- Kích thước: ATX\r', '- Socket: LGA1200\r', '- Chipset: B460\r', '- Khe RAM tối đa: 4\r', '- Loại RAM hỗ trợ: DDR4']
# Bao hanh:           24 tháng
# ********************************************************************************
# Code:               MBAS535
# Name:               Mainboard ASUS ROG STRIX X570-E GAMING (AMD X570, Socket AM4, ATX, 4 khe RAM DDR4)
# Base_price:         0
# Sale_price:         9349000
# Img_directory:      img/MAIN/250_47571_rog_strix_x570_e_gaming_aura_sync_01.png
# URL:                https://www.hanoicomputer.vn/mainboard-bo-mach-chu/1/
# Thong so san pham:  ['- Kích thước: ATX\r', '- Socket: AM4\r', '- Chipset: X570\r', '- Khe RAM tối đa: 4\r', '- Loại RAM hỗ trợ: DDR4']
# Bao hanh:           24 tháng
# ********************************************************************************
# Code:               MBAS534
# Name:               Mainboard ASUS ROG X570 CROSSHAIR VIII HERO (AMD X570, Socket AM4, ATX, 4 khe RAM DDR4)
# Base_price:         0
# Sale_price:         11399000
# Img_directory:      img/MAIN/250_47570_rog_crosshair_viii_hero_aura_sync_01.png
# URL:                https://www.hanoicomputer.vn/mainboard-bo-mach-chu/1/
# Thong so san pham:  ['- Ổ cắm AMD AM4: Hỗ trợ các bộ xử lý AMD Ryzen™ thế hệ thứ 2 và thứ 3 và tới hai ổ M.2, USB 3.2 Gen2 và AMD StoreMI để tối tối đa khả năng kết nối và tốc độ.\r', '- Thiết kế tản nhiệt toàn diện: Quạt tản nhiệt chipset chủ động, quạt tản nhiệt M.2 bằng nhôm và khu vực làm mát ROG.\r', '- Bộ nguồn ổn định: Thiết kế bộ nguồn với 14+2 pha cấp điện IR3555 PowIRstages, ProCool II, cuộn cảm lõi sắt từ và tụ điện kim loại đen 10K do Nhật Bản sản xuất.\r', '- Mạng hiệu suất cao: Wi-Fi 6 tích hợp (802.11ax) hỗ trợ MU-MIMO, 2.5 Gbps Ethernet và Gigabit Ethernet, cả hai đều được trang bị công nghệ bảo vệ ASUS LANGuard và hỗ trợ phần mềm GameFirst V.\r', '- Tối ưu 5 Chiều: Hiệu chỉnh tự động toàn hệ thống, cung cấp các hồ sơ ép xung và làm mát được tùy chỉnh cho hệ thống của bạn.\r']
# Bao hanh:           24 tháng
# ********************************************************************************
# Code:               MBAS533
# Name:               Mainboard ASUS ROG X570 CROSSHAIR VIII HERO Wifi (AMD X570, Socket AM4, ATX, 4 khe RAM DDR4)
# Base_price:         0
# Sale_price:         11899000
# Img_directory:      img/MAIN/250_47569_rog_crosshair_viii_hero__wi_fi__aura_sync_01.png
# URL:                https://www.hanoicomputer.vn/mainboard-bo-mach-chu/1/
# Thong so san pham:  ['- Mainboard Asus Rog Crosshair VIII Hero (WI-FI)\r', '- Chuẩn mainboard: ATX\r', '- Socket: AM4 , Chipset: X570\r', '- Hỗ trợ RAM: DDR4 , tối đa 64GB\r', '- Cổng cắm lưu trữ: 1 x M.2 NVMe; 1 x M.2 SATA/NVMe; 6 x SATA 3 6Gb/s']
# Bao hanh:           24 tháng
# ********************************************************************************
# Code:               MBAS532
# Name:               Mainboard ASUS ROG X570 CROSSHAIR VIII FORMULA (AMD X570, Socket AM4, ATX, 4 khe RAM DDR4)
# Base_price:         0
# Sale_price:         21699000
# Img_directory:      img/MAIN/250_47568_rog_crosshair_viii_formula_aura_sync_01.png
# URL:                https://www.hanoicomputer.vn/mainboard-bo-mach-chu/1/
# Thong so san pham:  ['- Socket: AM4 hỗ trợ CPU AMD thế hệ 3\r', '- Kích thước: ATX\r', '- Khe cắm RAM: 4 khe (Tối đa 128GB)\r', '- Khe cắm mở rộng: 2 x PCIe 4.0/3.0 x16\r', '- Khe cắm ổ cứng: 1 x M.2, 8 x SATA 6Gb/s']
# Bao hanh:           24 tháng
# ********************************************************************************
# Code:               MBAS596
# Name:               Mainboard ASUS TUF GAMING B550-PLUS (AMD B550, Socket AM4, ATX, 4 khe RAM DRR4)
# Base_price:         4299000
# Sale_price:         4099000
# Img_directory:      img/MAIN/250_53324_tuf_b550_plus_gaming_1.jpg
# URL:                https://www.hanoicomputer.vn/mainboard-bo-mach-chu/1/
# Thong so san pham:  ['- Kích thước: ATX\r', '- Socket: AM4\r', '- Chipset: B550\r', '- Khe RAM tối đa: 4\r', '- Loại RAM hỗ trợ: DDR4']
# Bao hanh:           36 tháng
# ********************************************************************************
# Code:               MBAS597
# Name:               Mainboard ASUS TUF GAMING B550M-PLUS (AMD B550, Socket AM4, m-ATX, 4 khe RAM DRR4)
# Base_price:         4199000
# Sale_price:         3999000
# Img_directory:      img/MAIN/250_53325_tuf_gaming_b550m_plus_01.jpg
# URL:                https://www.hanoicomputer.vn/mainboard-bo-mach-chu/1/
# Thong so san pham:  ['- Kích thước: M-ATX\r', '- Socket: AM4\r', '- Chipset: B550\r', '- Khe RAM tối đa: 4\r', '- Loại RAM hỗ trợ: DDR4']
# Bao hanh:           36 tháng
# ********************************************************************************
# Code:               MBAS598
# Name:               Mainboard ASUS TUF GAMING B550M-PLUS (WI-FI) (AMD B550, Socket AM4, m-ATX, 4 khe RAM DRR4)
# Base_price:         4599000
# Sale_price:         4499000
# Img_directory:      img/MAIN/250_53326_tuf_gaming_b550m_plus__wi_fi__1.jpg
# URL:                https://www.hanoicomputer.vn/mainboard-bo-mach-chu/1/
# Thong so san pham:  ['- Kích thước: M-ATX\r', '- Socket: AM4\r', '- Chipset: B550\r', '- Khe RAM tối đa: 4\r', '- Loại RAM hỗ trợ: DDR4']
# Bao hanh:           36 tháng
# ********************************************************************************
# Code:               MBAS573
# Name:               Mainboard ASUS ProArt Z490-CREATOR 10G (Intel Z490, Socket 1200, ATX, 4 khe RAM DDR4)
# Base_price:         0
# Sale_price:         8899000
# Img_directory:      img/MAIN/250_52357_proart_z490_creator_10g_01.jpg
# URL:                https://www.hanoicomputer.vn/mainboard-bo-mach-chu/1/
# Thong so san pham:  ['- Chuẩn mainboard: ATX\r', '- Socket: 1200, Chipset: Z490\r', '- Hỗ trợ RAM: 4 khe DDR4, tối đa 128GB\r', '- Lưu trữ:  2 x M.2 NVMe, 6 x SATA 3 6Gb/s\r', '- Cổng xuất hình: 1 x HDMI, 1 x DP']
# Bao hanh:           24 tháng
# ********************************************************************************
# Code:               MBAS554
# Name:               Mainboard ASUS ROG STRIX B360-I GAMING (Intel B360 , Socket 1151, Mini ATX, 2 khe RAM DDR4)
# Base_price:         3699000
# Sale_price:         3299000
# Img_directory:      img/MAIN/250_51060_rog_strix_b360_i_gaming_01.png
# URL:                https://www.hanoicomputer.vn/mainboard-bo-mach-chu/1/
# Thong so san pham:  ['- Kích thước: ITX\r', '- Socket: 1151v2\r', '- Chipset: B360\r', '- Khe RAM tối đa: 2\r', '- Loại RAM hỗ trợ: DDR4']
# Bao hanh:           24 tháng
# ********************************************************************************
# Code:               MBAS525
# Name:               Mainboard ASUS ROG STRIX B365-F GAMING (Intel B365, Socket 1151, ATX, 4 khe RAM DDR4)
# Base_price:         3599000
# Sale_price:         3299000
# Img_directory:      img/MAIN/250_47176_rog_strix_b365_f_gaming_01.png
# URL:                https://www.hanoicomputer.vn/mainboard-bo-mach-chu/1/
# Thong so san pham:  ['- Socket: 1151 9th/8th Gen Intel Core, Pentium Gold and Celeron Processors\r', '- Kích thước: ATX\r', '- Khe cắm RAM: 4 khe (Tối đa 64GB)\r', '- Khe cắm mở rộng: 1 x PCIe 3.0/2.0 x16/1 x PCIe 3.0/2.0 x16 / 3 x PCIe 3.0/2.0 x1\r', '- Khe cắm ổ cứng: 1 x M.2 Socket 3/ 1 x M.2 Socket 3/ 6 x SATA 6Gb/s']
# Bao hanh:           24 tháng
# ********************************************************************************
# Code:               MBAS522
# Name:               Mainboard ASUS ROG MAXIMUS XI APEX (Intel Z390,Socket 1151, ATX, 2 khe RAM DDR4)
# Base_price:         0
# Sale_price:         9699000
# Img_directory:      img/MAIN/250_45816_rog_maximus_xi_apex_z390_10.png
# URL:                https://www.hanoicomputer.vn/mainboard-bo-mach-chu/1/
# Thong so san pham:  ['- Chuẩn mainboard: ATX \r', '- Socket: LGA 1151-v2 , Chipset: Z390 \r', '- Hỗ trợ RAM: DDR4 , tối đa 64GB \r', '- Cổng cắm lưu trữ: 1 x M.2 NVMe; 1 x M.2 SATA/NVMe; 6 x SATA 3 6Gb/s; Hỗ trợ Intel Optane \r', '- Cổng xuất hình: Không có']
# Bao hanh:           24 tháng
# ********************************************************************************
# Code:               MBAS548
# Name:               Mainboad ASUS ROG STRIX X299 - E GAMING II (Intel X299, Socket 2066, ATX,8 khe RAM DDR4)
# Base_price:         10899000
# Sale_price:         9399000
# Img_directory:      img/MAIN/250_49687_01_rog_strix_x299_e_gaming_ii.png
# URL:                https://www.hanoicomputer.vn/mainboard-bo-mach-chu/1/
# Thong so san pham:  ['- Sẵn sàng cho bộ xử lý Intel® Core ™ X-series mới nhất để tối đa hóa khả năng kết nối và tốc độ với tối đa ba ổ M.2, USB 3.2 Gen 2, Intel® VROC và Intel® Optane ™\r', '- Cá nhân hóa chưa từng có: Ánh sáng Aura Sync RGB dành riêng cho OLED và ASUS, bao gồm các chân kết nối RGB và các chân kết nối Gen 2 A-RGB\r', '- Giải pháp tối ưu: 12 phase nguồn với đầu nối nguồn ProCool II, cuộn cảm chất lượng cao và tụ điện bền để hỗ trợ bộ xử lý đa lõi\r', '- Làm mát toàn diện: Tản nhiệt chủ động VRM, tản nhiệt vây xếp chồng lên nhau, với ống tản nhiệt 8 mm, tản nhiệt M.2 kép trên bo mạch\r', '- Kết nối chơi game: Ba cổng M.2, USB 3.2 Type-C và đầu nối bảng mặt trước Type-C\r']
# Bao hanh:           24 tháng
# ********************************************************************************
# Code:               MBAS529
# Name:               Mainboard ASUS EX-B365M-V5 (Intel B365, Socket 1151, m-ATX, 2 khe RAM DDR4)
# Base_price:         1899000
# Sale_price:         1649000
# Img_directory:      img/MAIN/250_47480_01_ex_b365m_v5.png
# URL:                https://www.hanoicomputer.vn/mainboard-bo-mach-chu/1/
# Thong so san pham:  ['- Chipset: Intel B365\r', '- Socket: LGA1151\r', '- Hỗ trợ CPU: Intel® Socket 1151 9th / 8th Gen Intel® Core™, Pentium® Gold and Celeron® Processors. Supports Intel® 14 nm CPU.\r', '- Cạc đồ họa: VGA onboard\r', '- Kích thước: mATX']
# Bao hanh:           24 tháng
# ********************************************************************************
# Code:               MBAS495
# Name:               Mainboard ASUS PRIME B450M-A (AMD B450, Socket AM4, m-ATX, 4 khe RAM DDR4)
# Base_price:         1899000
# Sale_price:         1699000
# Img_directory:      img/MAIN/250_43238_01_prime_b450m_a.png
# URL:                https://www.hanoicomputer.vn/mainboard-bo-mach-chu/1/
# Thong so san pham:  ['- Bo mạch chủ AMD AM4 mATX DDR4 3200MHz, M.2, HDMI 2.0b, SATA 6Gbps và USB 3.1 Gen 2']
# Bao hanh:           24 tháng
# ********************************************************************************
# Code:               MBAS536
# Name:               Mainboard ASUS ROG STRIX Z390-E GAMING (Intel Z390, Socket 1151, ATX, 4 khe RAM DDR4)
# Base_price:         5699000
# Sale_price:         5599000
# Img_directory:      img/MAIN/250_48061_1__bo_mach_chu_gaming_cao_cap_asus_rog_strix_z390_e_gaming_aura_sync_hop_san_pham.png
# URL:                https://www.hanoicomputer.vn/mainboard-bo-mach-chu/1/
# Thong so san pham:  ['- Asus ROG STRIX Z390-E GAMING\r', '- Socket: LGA1151 hỗ trợ CPU intel thế hệ 8 và 9\r', '- Kích thước: ATX\r', '- Khe cắm RAM: 4 khe (Tối đa 64GB)\r', '- Khe cắm mở rộng: 3 x PCIe 3.0/2.0 x16, 3 x PCIe 3.0/2.0 x1\r']
# Bao hanh:           24 tháng
# ********************************************************************************
# Code:               MBAS505
# Name:               Mainboard ROG MAXIMUS XI HERO (Intel Z390, Socket 1151, ATX, 4 khe RAM DDR4)
# Base_price:         0
# Sale_price:         6999000
# Img_directory:      img/MAIN/250_44302__hinh_dai_dien__bo_mach_chu_gaming_cao_cap_mainboard_asus_rog_maximus_xi_hero_z390_aura_sync_hop_san_pham_01.png
# URL:                https://www.hanoicomputer.vn/mainboard-bo-mach-chu/1/
# Thong so san pham:  ['- Kích thước: ATX\r', '- Socket: LGA 1151v2\r', '- Chipset: Z390\r', '- Khe RAM tối đa: 4\r', '- Loại RAM hỗ trợ: DDR4']
# Bao hanh:           24 tháng
# ********************************************************************************
# Code:               MBAS539
# Name:               Mainboard ASUS ROG Z390 MAXIMUS XI HERO (WI-FI) (Intel Z390, Socket 1151, ATX, 4 khe RAM DDR4)
# Base_price:         0
# Sale_price:         7799000
# Img_directory:      img/MAIN/250_48772__hinh_dai_dien__bo_mach_chu_gaming_cao_cap_mainboard_asus_rog_maximus_xi_hero_z390_aura_sync_hop_san_pham_01.png
# URL:                https://www.hanoicomputer.vn/mainboard-bo-mach-chu/1/
# Thong so san pham:  ['- Socket LGA1151 cho các bộ xử lý máy tính bàn Intel® Core™ thế hệ thứ 8/9.\r', '- Công nghệ đèn RGB đồng bộ hóa hỗ trợ nhiều thiết bị PC tương thích Aura Sync và hỗ trợ các dải đèn địa chỉ và Phillip Hue\r', '- Bo mạch chủ được làm mát hoàn hảo với các vùng cổng cấp nước chuyên dụng, quạt tản nhiệt M.2 và điều khiển quạt đa dạng\r', '- Khả năng kết nối gaming: Intel Gigabit Ethernet , LANGaurd, M.2 kép, USB 3.1 Gen 2, Wi-Fi với MU-MI-MO 802.11\r', '- Tối ưu hóa 5 bước: Tự động điều chỉnh toàn hệ thống, hỗ trợ các tính năng ép xung và làm mát công nghệ AI dành riêng cho giàn máy của bạn\r']
# Bao hanh:           24 tháng
# ********************************************************************************
# Code:               MBAS601
# Name:               Mainboard ASUS PRIME B550M-A (WI-FI) (AMD B550, Socket AM4,m- ATX, 4 khe RAM DRR4)
# Base_price:         0
# Sale_price:         3799000
# Img_directory:      img/MAIN/250_53329_prime_b550m_a_1.jpg
# URL:                https://www.hanoicomputer.vn/mainboard-bo-mach-chu/1/
# Thong so san pham:  ['- Kích thước: M-ATX\r', '- Socket: AM4\r', '- Chipset: B550\r', '- Khe RAM tối đa: 4\r', '- Loại RAM hỗ trợ: DDR4']
# Bao hanh:           36 tháng
# ********************************************************************************
# Code:               MBAS602
# Name:               Mainboard ASUS PRIME B550M-K (AMD B550, Socket AM4,m- ATX, 4 khe RAM DRR4)
# Base_price:         0
# Sale_price:         3199000
# Img_directory:      img/MAIN/250_53330_prime_b550m_k_1.jpg
# URL:                https://www.hanoicomputer.vn/mainboard-bo-mach-chu/1/
# Thong so san pham:  ['- Kích thước: M-ATX\r', '- Socket: AM4\r', '- Chipset: B550\r', '- Khe RAM tối đa: 4\r', '- Loại RAM hỗ trợ: DDR4']
# Bao hanh:           36 tháng
# ********************************************************************************
# Code:               MBAS530
# Name:               Mainboard ASUS PRIME X570-P/CSM (AMD X570, Socket AM4, ATX, 4 khe RAM DDR4)
# Base_price:         0
# Sale_price:         4899000
# Img_directory:      img/MAIN/250_47566_prime_x570_p_aura_sync_01.png
# URL:                https://www.hanoicomputer.vn/mainboard-bo-mach-chu/1/
# Thong so san pham:  ['- Socket: AM4 hỗ trợ CPU AMD thế hệ 3\r', '- Kích thước: ATX\r', '- Khe cắm RAM: 4 khe (Tối đa 128GB)\r', '- Khe cắm mở rộng: 1 x PCIe 4.0/3.0 x16\r', '- Khe cắm ổ cứng: 1 x M.2, 6 x SATA 6Gb/s']
# Bao hanh:           24 tháng
# ********************************************************************************
# Code:               MBAS542
# Name:               Mainboard Asus Pro WS X570-ACE
# Base_price:         0
# Sale_price:         8989000
# Img_directory:      img/MAIN/250_49338_pro_ws_x570_ace_1.png
# URL:                https://www.hanoicomputer.vn/mainboard-bo-mach-chu/1/
# Thong so san pham:  ['- Ba khe cắm PCIe 4.0 x16 với sự sắp xếp làn đường được tối ưu hóa 3 chiều x8 / x8 / x8 để tăng tốc khối lượng công việc ngày càng đa dạng\r', '- Bộ nhớ ECC đáng tin cậy và đáp ứng phù hợp cho các nhiệm vụ quan trọng\r', '- ASUS Control Center Express: Một tiện ích phần mềm được trang bị bộ điều khiển LAN GbE để quản lý ngoài băng tần để tăng cường kiểm soát mức phần cứng nhằm cải thiện hiệu quả CNTT\r', '- Lưu trữ cực nhanh: Lên đến 64Gbps M.2 & 32Gbps U.2, cộng với cổng USB 3.2 Gen 2 lên tới 10Gbps với cổng Type-A và Type-C\r', '- Tản nhiệt VRM cực kỳ hiệu quả: Tản nhiệt lớn, tản nhiệt và thiết kế quạt PCH tích hợp tối đa hóa diện tích bề mặt để tản nhiệt để cho phép hiệu suất vượt trội\r']
# Bao hanh:           24 tháng
# ********************************************************************************
# Code:               MBAS541
# Name:               Mainboard ASUS TUF GAMING X570 PLUS (Wi-Fi) (AMD X570, Socket AM4, ATX, 4 khe RAM DDR4)
# Base_price:         0
# Sale_price:         5999000
# Img_directory:      img/MAIN/250_49003_tuf_gaming_x570_plus__wi_fi__aura_sync_01.png
# ...
# Bao hanh:           24 tháng
# ********************************************************************************
# Code:               MBMS319
# Name:               Mainboard MSI B360M BAZOOKA
# Base_price:         0
# Sale_price:         2299000
# Img_directory:      img/MAIN/250_42056_mainboard_msi_b360m_bazooka_0002_3.jpg
# URL:                https://www.hanoicomputer.vn/mainboard-bo-mach-chu/7/
# Thong so san pham:  ['- CPU\tSupports 8th Generation Intel® Core™ Processors, and Intel® Pentium® Gold and Celeron® Processors for Socket LGA1151\r', '- \r', '- Chipset\tIntel® B360 Chipset\r', '- Memory\t•\t4 x DDR4 memory slots, support up to 64GB \r', '- o\tSupports DDR4 2666/ 2400/ 2133 MHz1\r']
# Bao hanh:           24 tháng
# ********************************************************************************
# Code:               MBGI514
# Name:               Mainboard Gigabyte X399 Designare EX
# Base_price:         0
# Sale_price:         12690000
# Img_directory:      img/MAIN/250_44384_mainboard_gigabyte_x399_designare_ex_0000_1.jpg
# URL:                https://www.hanoicomputer.vn/mainboard-bo-mach-chu/7/
# Thong so san pham:  ['- Hỗ trợ Bộ xử lý AMD Ryzen ™ Threadripper ™\r', '- Hỗ trợ DDR4 Kênh 4 ECC / non-ECC, 8 DIMM, 3600 MHz + (OC)\r', '- Giao diện USB 3.1 Front-C ™ nhanh trước và sau\r', '- Hỗ trợ 4 GPU với thiết kế Dual Armor và Ultra Durable ™\r', '- Thiết kế pha điện kỹ thuật số cấp máy chủ & Kết nối nguồn rắn mạ vàng\r']
# Bao hanh:           24 tháng
# ********************************************************************************
# Code:               MBAS445
# Name:               Mainboard ASUS H110M- CS (T) (Intel H110, Socket 1151, m-ATX, 2 khe RAM DD4)
# Base_price:         1399000
# Sale_price:         999000
# Img_directory:      img/MAIN/250_52246_mainboard_asus_h110m_cs_t_intel_h110_socket_1151_m_atx_2_khe_ram_dd4_0001_2.jpg
# URL:                https://www.hanoicomputer.vn/mainboard-bo-mach-chu/7/
# Thong so san pham:  ['- Chuẩn mainboard: m-ATX\r', '- Socket: 1151 v2 , Chipset: H110\r', '- Hỗ trợ RAM: 2 khe DDR4, tối đa 32GB\r', '- Lưu trữ: 6 x SATA 3 6Gb/s\r', '- Cổng xuất hình: 1 x D-Sub']
# Bao hanh:           24 tháng
# ********************************************************************************
# Code:               MBAS572
# Name:               Mainboard ASUS PRIME Z490M-PLUS (Intel Z490, Socket 1200, m-ATX, 4 khe RAM DDR4)
# Base_price:         0
# Sale_price:         4179000
# Img_directory:      img/MAIN/250_52356_prime_z490m_plus_01_p_1.jpg
# URL:                https://www.hanoicomputer.vn/mainboard-bo-mach-chu/7/
# Thong so san pham:  ['- Chuẩn mainboard: ATX\r', '- Socket: 1200, Chipset: Z490\r', '- Hỗ trợ RAM: 4 khe DDR4, tối đa 128GB\r', '- Lưu trữ:  2 x M.2 NVMe, 6 x SATA 3 6Gb/s\r', '- Cổng xuất hình: 1 x HDMI, 1 x DisplayPort']
# Bao hanh:           24 tháng
# ********************************************************************************
# Code:               MBAR254
# Name:               Mainboard ASROCK Z490 PHANTOM GAMING 4/2.5G (Intel Z490, Socket 1200, ATX, 4 khe Ram DDR4)
# Base_price:         0
# Sale_price:         0
# Img_directory:      img/MAIN/250_52444_mainboard_asrock_z490_phantom_gaming_42_5g_intel_z490_socket_1200_atx_4_khe_ram_ddr4_0004_5.jpg
# URL:                https://www.hanoicomputer.vn/mainboard-bo-mach-chu/7/
# Thong so san pham:  ['- Chuẩn mainboard: ATX\r', '- Socket: 1200, Chipset: Z490\r', '- Hỗ trợ RAM: 4 khe DDR4, tối đa 128GB\r', '- Lưu trữ: 1 x M.2 NVMe, 6 x SATA 3 6Gb/s\r', '- Cổng xuất hình: 1 x HDMI']
# Bao hanh:           24 tháng
# ********************************************************************************
# Code:               MBMS391
# Name:               Mainboard MSI MPG B550I GAMING EDGE WIFI (AMD B550 Socket AM4 Mini-ATX 2 khe RAM DDR4)
# Base_price:         0
# Sale_price:         5899000
# Img_directory:      img/MAIN/250_53632_mpg_b550i_gaming_edge_wifi.jpg
# URL:                https://www.hanoicomputer.vn/mainboard-bo-mach-chu/7/
# Thong so san pham:  ['- Kích thước: ITX\r', '- Socket: AM4\r', '- Chipset: B550\r', '- Khe RAM tối đa: 2\r', '- Loại RAM hỗ trợ: DDR4']
# Bao hanh:           24 tháng
# ********************************************************************************
# Code:               MBGI588
# Name:               Mainboard Gigabyte A520 AORUS ELITE (AMD A520, Socket 1200, ATX, 4 khe RAM DDR4)
# Base_price:         0
# Sale_price:         2499000
# Img_directory:      img/MAIN/250_55504_mainboard_gigabyte_a520_aorus_elite_4.png
# URL:                https://www.hanoicomputer.vn/mainboard-bo-mach-chu/7/
# Thong so san pham:  ['- Kích thước: ATX\r', '- Socket: AM4\r', '- Chipset: A520\r', '- Khe RAM tối đa: 4\r', '- Loại RAM hỗ trợ: DDR4']
# Bao hanh:           24 tháng
# ********************************************************************************
# Code:               MBAS449
# Name:               Mainboard ASUS Z370 ROG MAXIMUS X HERO
# Base_price:         0
# Sale_price:         7499000
# Img_directory:      img/MAIN/250_38290_z370_maximus_x_hero__custom_.jpg
# URL:                https://www.hanoicomputer.vn/mainboard-bo-mach-chu/7/
# Thong so san pham:  ['- Socket LGA1151 cho các bộ vi xử lý máy tính để bàn Intel® Core™ Thế hệ thứ 8\r', '- Đồng bộ ánh sáng RGB với nhiều loại thiết bị máy tính hỗ trợ Aura Sync – giờ đây còn hỗ trợ các dải đèn LED\r', '- Bộ làm mát M.2 trên bo mạch: Làm mát ổ đĩa M.2 của bạn, cho hiệu năng lưu trữ ổn định và tăng cường độ tin cậy\r', '-  m thanh gaming: SupremeFX và Sonic Studio III –  m thanh độ trung thực cao khiến bạn đắm chìm sâu hơn vào hành động.\r', '- Khả năng kết nối gaming: Intel Gigabit Ethernet, LANGuard, Dual M.2, Đầu cắm USB 3.1 Thế hệ 2 Kiểu A và Kiểu C™\r']
# Bao hanh:           24 tháng
# ********************************************************************************
# Code:               MBAS463
# Name:               Mainboard ASUS WS C621E SAGE (Dual CPU Workstations)
# Base_price:         0
# Sale_price:         17989000
# Img_directory:      img/MAIN/250_40808_mainboard_asusws_c621e_sage_dual_cpuworkstations_0000_1.jpg
# URL:                https://www.hanoicomputer.vn/mainboard-bo-mach-chu/7/
# Thong so san pham:  ['- Mainboard Asus WS C621E SAGE, sử dụng chipset C621 của Intel dành cho Workstations. Mainboard này hỗ trợ tới 2 bộ vi xử lý Intel Xeon Scalable sử dụng socket LGA-3647, kèm theo khả năng ép xung cao cấp. Asus WS C621E SAGE đáp ứng xử lý công việc lớn dành cho doanh nghiệp, người làm trong các lĩnh vực thiết kế đồ họa, video, render, phân tích dữ liệu, ảo hóa hay AI - Trí tuệ nhân tạo cần tới.']
# Bao hanh:           24 tháng
# ********************************************************************************
# Code:               MBGI496
# Name:               Mainboard Gigabyte B360 Aorus Gaming 3
# Base_price:         0
# Sale_price:         2999000
# Img_directory:      img/MAIN/250_41793_mainboard_gigabyte_b360_aorus_gaming_3_0001_2.jpg
# URL:                https://www.hanoicomputer.vn/mainboard-bo-mach-chu/7/
# Thong so san pham:  ['- CPU\t1.\tSupport for 8th Generation Intel® Core™ i7 processors/Intel® Core™ i5 processors/ Intel® Core™ i3 processors/Intel® Pentium® processors/Intel® Celeron® processors in the LGA1151 package\r', '- 2.\tL3 cache varies with CPU\r', '- Chipset\tIntel® B360 Express Chipset\r', '- Memory\t•  4 x DDR4 DIMM sockets supporting up to 64 GB of system memory \r', '- •  Dual channel memory architecture \r']
# Bao hanh:           24 tháng
# ********************************************************************************
# Code:               MBMS315
# Name:               Mainboard MSI B360M MORTAR
# Base_price:         2399000
# Sale_price:         2299000
# Img_directory:      img/MAIN/250_41855_mainboard_msi_b360m_mortar_0002_3.jpg
# URL:                https://www.hanoicomputer.vn/mainboard-bo-mach-chu/7/
# Thong so san pham:  ['']
# Bao hanh:           24 tháng
# ********************************************************************************
# Code:               MBGI513
# Name:               Mainboard Gigabyte X399 Aorus Xtreme
# Base_price:         0
# Sale_price:         11590000
# Img_directory:      img/MAIN/250_44383_mainboard_gigabyte_x399_aorus_xtreme_0001_2.jpg
# URL:                https://www.hanoicomputer.vn/mainboard-bo-mach-chu/7/
# Thong so san pham:  ['- Hỗ trợ chip xử lý AMD Ryzen Threadripper TR4 \r', '- Quad Channel ECC/ Non-ECC Unbuffered DDR4, 8 DIMMs, 3600MHz+(OC)\r', '- Hỗ trợ đa GPU, 4-Way với lớp bảo vệ thiết kế theo chuẩn Ultra Durable bền vững\r', '- Kết nối siêu nhanh với Triple NVMe PCIe thế hệ 3 x4 M.2 với lá tản nhiệt\r', '- Ngõ cắm & mạch điện chuẩn Server đảm bảo tin cậy tuyệt đối\r']
# Bao hanh:           24 tháng
# ********************************************************************************
# Code:               MBAS611
# Name:               Mainboard ASUS ROG STIX TRX40-XE GAMING (AMD TRX40, Socket sTRX4, ATX, 8 khe RAM DDR4)
# Base_price:         0
# Sale_price:         13999000
# Img_directory:      img/MAIN/250_56268_mainboard_asus_rog_stix_trx40_xe_gaming_1.jpg
# URL:                https://www.hanoicomputer.vn/mainboard-bo-mach-chu/7/
# Thong so san pham:  ['- Mainboard socket AMD TRX 40\r', '- Sản phẩm cao cấp của Asus\r', '- Số khe RAM: 16\r', '- Kích thước: E-ATX']
# Bao hanh:           24 tháng
# ********************************************************************************
# Code:               MBMS370
# Name:               Mainboard MSI MEG Z490 ACE (Intel Z490, Socket 1200, ATX, 4 khe RAM DDR4)
# Base_price:         0
# Sale_price:         9899000
# Img_directory:      img/MAIN/250_52307_mainboard_msi_meg_z490_ace_intel_z490_socket_1200_atx_4_khe_ram_ddr4_0000_1.jpg
# URL:                https://www.hanoicomputer.vn/mainboard-bo-mach-chu/7/
# Thong so san pham:  ['- Chuẩn mainboard: ATX\r', '- Socket: 1200, Chipset: Z490\r', '- Hỗ trợ RAM: 4 khe DDR4, tối đa 128GB\r', '- Lưu trữ:  3 x M.2 NVMe, 6 x SATA 3 6Gb/s\r', '- Cổng xuất hình: Không']
# Bao hanh:           24 tháng
# ********************************************************************************
# Code:               MBAR255
# Name:               Mainboard ASROCK Z490 PHANTOM GAMING 4/ac (Intel Z490, Socket 1200, ATX, 4 khe Ram DDR4)
# Base_price:         0
# Sale_price:         0
# Img_directory:      img/MAIN/250_52445_mainboard_asrock_z490_phantom_gaming_4ac_intel_z490_socket_1200_atx_4_khe_ram_ddr4_0004_5.jpg
# URL:                https://www.hanoicomputer.vn/mainboard-bo-mach-chu/7/
# Thong so san pham:  ['- Chuẩn mainboard: ATX\r', '- Socket: 1200, Chipset: Z490\r', '- Hỗ trợ RAM: 4 khe DDR4, tối đa 128GB\r', '- Lưu trữ: 1 x M.2 NVMe, 6 x SATA 3 6Gb/s\r', '- Cổng xuất hình: 1 x HDMI']
# Bao hanh:           24 tháng
# ********************************************************************************
# Code:               MBGI571
# Name:               Mainboard Gigabyte H410M-H (Intel H410, Socket 1200, m-ATX, 2 khe Ram DDR4)
# Base_price:         0
# Sale_price:         1749000
# Img_directory:      img/MAIN/250_53230_gigabyte_h410m_h.jpg
# URL:                https://www.hanoicomputer.vn/mainboard-bo-mach-chu/7/
# Thong so san pham:  ['- Kích thước: Micro-ATX\r', '- Socket: LGA 1200\r', '- Chipset: H410\r', '- Khe RAM tối đa: 2\r', '- Loại RAM hỗ trợ: DDR4']
# Bao hanh:           36 tháng
# ********************************************************************************
# Code:               MBMS387
# Name:               Mainboard MSI MAG B550M MORTAR WIFI (AMD B550, Socket AM4, m-ATX, 4 khe RAM DDR4)
# Base_price:         0
# Sale_price:         4899000
# Img_directory:      img/MAIN/250_53457_msi_mag_b550m_mortar_wifi.jpg
# URL:                https://www.hanoicomputer.vn/mainboard-bo-mach-chu/7/
# Thong so san pham:  ['- Kích thước: M-ATX\r', '- Socket: AM4\r', '- Chipset: B550\r', '- Khe RAM tối đa: 4\r', '- Loại RAM hỗ trợ: DDR4']
# Bao hanh:           24 tháng
# ********************************************************************************
# Code:               MBMS392
# Name:               Mainboard MSI MPG B550 GAMING PLUS (AMD B550 Socket AM4 ATX 4 khe RAM DDR4)
# Base_price:         0
# Sale_price:         4099000
# Img_directory:      img/MAIN/250_53633_msi_mpg_b550_gaming_plus.jpg
# URL:                https://www.hanoicomputer.vn/mainboard-bo-mach-chu/7/
# Thong so san pham:  ['- Kích thước: ATX\r', '- Socket: AM4\r', '- Chipset: B550\r', '- Khe RAM tối đa: 4\r', '- Loại RAM hỗ trợ: DDR4']
# Bao hanh:           24 tháng
# ********************************************************************************
# Code:               MBGI589
# Name:               Mainboard Gigabyte A520I AC (AMD A520, Socket AM4, Mini-ITX, 2 khe RAM DDR4)
# Base_price:         0
# Sale_price:         2799000
# Img_directory:      img/MAIN/250_55505_mainboard_gigabyte_a520i_ac_3.png
# URL:                https://www.hanoicomputer.vn/mainboard-bo-mach-chu/7/
# Thong so san pham:  ['- Kích thước: M-ATX\r', '- Socket: AM4\r', '- Chipset: A520\r', '- Khe RAM tối đa: 2\r', '- Loại RAM hỗ trợ: DDR4']
# Bao hanh:           24 tháng
# ********************************************************************************
# Code:               MBAS454
# Name:               Mainboard ASUS ROG STRIX Z370-I GAMING
# Base_price:         0
# Sale_price:         5990000
# Img_directory:      img/MAIN/250_39744_81v96sfvu2l__sl1500_.jpg
# URL:                https://www.hanoicomputer.vn/mainboard-bo-mach-chu/7/
# Thong so san pham:  ['- Kích thước: ITX\r', '- Socket: LGA 1151v2\r', '- Chipset: Z370\r', '- Khe RAM tối đa: 2\r', '- Loại RAM hỗ trợ: DDR4']
# Bao hanh:           24 tháng
# ********************************************************************************
# Code:               MBGI539
# Name:               Mainboard GIGABYTE X570 AORUS MASTER (AMD X570, Socket AM4, ATX, 4 khe RAM DDR4)
# Base_price:         0
# Sale_price:         10499000
# Img_directory:      img/MAIN/250_48476_mainboard_gigabyte_x570_aorus_master_0000_1.jpg
# URL:                https://www.hanoicomputer.vn/mainboard-bo-mach-chu/7/
# Thong so san pham:  ['- Hỗ trợ AMD thế hệ thứ 3 Ryzen ™ / Thế hệ thứ hai Ryzen ™ / Thế hệ thứ hai Ryzen ™ với Radeon ™ Vega Graphics / Ryzen ™ với Bộ xử lý đồ họa Radeon ™ Vega\r', '- Hỗ trợ RAM ECC / Non-ECC không có bộ đệm\r', '- 14 phase điện PowIRstage\r', '- Thiết kế tản nhiệt tiên tiến với tản nhiệt Fins-Array và Heat Touch trực tiếp\r', '- 3 khe NVMe PCIe 4.0 / 3.0 x4 M.2 siêu nhanh với 3 mineesg tản nhiệt\r']
# Bao hanh:           24 tháng
# ********************************************************************************
# Code:               MBGI495
# Name:               Mainboard Gigabyte B360M Aorus Gaming 3
# Base_price:         0
# Sale_price:         2199000
# Img_directory:      img/MAIN/250_41792_mainboard_gigabyte_b360m_aorus_gaming_3_0000_1.jpg
# URL:                https://www.hanoicomputer.vn/mainboard-bo-mach-chu/7/
# Thong so san pham:  ['- CPU\t1.\tSupport for 8th Generation Intel® Core™ i7 processors/Intel® Core™ i5 processors/Intel® Core™ i3 processors/Intel® Pentium® processors/Intel® Celeron® processors in the LGA1151 package\r', '- 2.\tL3 cache varies with CPU\r', '- Chipset\tIntel® B360 Express Chipset\r', '- Bộ nhớ\t1.\t4 x DDR4 DIMM sockets supporting up to 64 GB of system memory\r', '- 2.\tDual channel memory architecture\r']
# Bao hanh:           24 tháng
# ********************************************************************************
# Code:               MBMS290
# Name:               Mainboard MSI X399 GAMING PRO CARBON AC
# Base_price:         0
# Sale_price:         12599000
# Img_directory:      img/MAIN/250_37728_mainboard_msi_x399_gaming_pro_carbon_ac_0001_2.jpg
# URL:                https://www.hanoicomputer.vn/mainboard-bo-mach-chu/7/
# Thong so san pham:  ['- Chuẩn mainboard: ATX\r', '- Socket: TR4 , Chipset: X399\r', '- Hỗ trợ RAM: DDR4 , tối đa 128GB\r', '- Cổng cắm lưu trữ: 3 x M.2 SATA/NVMe; 8 x SATA 3 6Gb/s\r', '- Cổng xuất hình: Không có']
# Bao hanh:           24 tháng
# ********************************************************************************

# %%
# Out:
# [None, None, None, None]

# %%
obj_dct

# %%
import pandas as pd
csv_file_name = 'Csv/'+'None'+'.csv'
df = pd.DataFrame(obj_dct)
# df.to_csv(csv_file_name)

# %%
print(df)
# Out:
#         Code  ...                                  Thong so san pham
# 0    CPUI307  ...  [- Socket: FCLGA2066\r, - Số lõi/luồng: 10/20-...
# 1    CPUI313  ...  [- Tiến trình sản xuất 14 nm\r, - 6 nhân, 6 lu...
# 2    CPUI243  ...  [- Dòng Core i thế hệ thứ 8 dành cho máy bàn c...
# 3    CPUI316  ...  [- Phiên bản cắt giảm đi nhân đồ họa tích hợp ...
# 4    CPUI363  ...  [- CPU Core i thế hệ thứ 10 của Intel\r, - 12 ...
# ..       ...  ...                                                ...
# 195  CPUA200  ...  [- Phiên bản AMD Ryzen 5 2600x có 6 nhân (12 l...
# 196  CPUI366  ...  [- CPU Pentium cơ bản của Intel\r, - 2 nhân & ...
# 197  CPUI334  ...  [- Dòng sản phẩm chuyên biệt dành cho server/m...
# 198  CPUI350  ...  [- Dòng sản phẩm chuyên biệt dành cho server/m...
# 199  CPUA233  ...                                                 []
#
# [200 rows x 6 columns]
